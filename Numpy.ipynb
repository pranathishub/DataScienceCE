# %%
import numpy as np
a = np.array([1,2,3])
b = np.array([[1,2],[3,4]])
print(a,b)

P = np.array([1,2,3,4,5])
print(P[-1])

print(a.shape)
print(a.ndim)
print(b.shape)
print(b.ndim)
# Out:
# [1 2 3] [[1 2]
#  [3 4]]
# 5
# (3,)
# 1
# (2, 2)
# 2

# %%
import numpy as np
n1 = np.array([1,2,3,4])
n2 = np.array([5,6,7,8])
